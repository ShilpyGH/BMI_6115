# %% [markdown]
# ## NLP pipeline

# %%
import pymysql
import pandas as pd
import getpass

# %%
import glob
import re
import os

# %%
from PyRuSH.RuSH import RuSH

from pyConTextNLP import pyConTextGraph
from pyConTextNLP.utils import get_document_markups

from DocumentClassifier import FeatureInferencer
from DocumentClassifier import DocumentInferencer
from DocumentClassifier import DocumentClassifier

from nlp_pneumonia_utils import markup_sentence
from nlp_pneumonia_utils import read_doc_annotations
from nlp_pneumonia_utils import list_errors

from itemData import get_item_data

# %%
from pipeUtils import Annotation
from pipeUtils import Document
from wrapperPyConText import ConTextPipe
from wrapperPyConText import convertMarkupsAnnotations

# %%
# from visual import Vis
from visual import snippets_markup
from visual import view_pycontext_outputs
from visual import display_doc_text
from visual import convertMarkups2DF

# packages for interaction
from IPython.display import display, HTML
import ipywidgets

# %%
# begin to define MyPipe class
class MyPipe:
    def __init__(self, sentence_rules, target_rules, context_rules, feature_inference_rule, document_inference_rule):
        # initiate necessary components here
        self.sentence_segmenter = RuSH(sentence_rules)
        self.feature_inferencer = FeatureInferencer(feature_inference_rule)
        self.document_inferencer = DocumentInferencer(document_inference_rule)

        self.targets=get_item_data(target_rules)
        self.modifiers=get_item_data(context_rules)
        
        self.target_rules_abi=self.getTargetRegexes()
        
    def process(self, doc_text, doc):        
        #process your input doc_text, return the required results                                   
        sentences = self.sentence_segmenter.segToSentenceSpans(doc_text)
             
        # initiate a pyConTextGraph to hold the pyConText output
        context_doc = pyConTextGraph.ConTextDocument()
        
        for sentence in sentences:
            # print(sentence)
            sentence_text = doc_text[sentence.begin:sentence.end].lower()
            # Process every sentence by adding markup
            m = markup_sentence(sentence_text, modifiers=self.modifiers, targets=self.targets)
            doc.annotations.extend(convertMarkupsAnnotations(m, offset=sentence.begin))
            context_doc.addMarkup(m)
            context_doc.getSectionMarkups()
            #print(doc.toString())
                       
          
        ## Apply document classification
        
        # convert graphic markups into dataframe    
        markups = get_document_markups(context_doc)
        annotations, relations, doc_txt = convertMarkups2DF(markups) 
        
        # apply inferences for document classication
        inferenced_types = self.feature_inferencer.process(annotations, relations)
        doc_class = self.document_inferencer.process(inferenced_types)
                        
        return doc_class, context_doc, annotations, relations
    
    def abi_extraction(self, document):
        document_id = document.document_id
        ann_index=0
        for reg in self.target_rules_abi:
            for match in reg.finditer(document.text):
                ann_id = 'NLP_'+ str(document_id) + '_' + str(ann_index)
                ann_index=ann_index+1
                new_annotation = Annotation(start_index=int(match.start()), 
                                    end_index=int(match.end()), 
                                    type='abi_annotation',
                                    ann_id = ann_id
                                    )
                new_annotation.spanned_text = document.text[new_annotation.start_index:new_annotation.end_index]
                print(new_annotation.spanned_text)

                # find the numeric value from the string/sentence
                
                if re.findall(r'\b\d+\.\d+\b', new_annotation.spanned_text):
                    str_abi_value = re.findall(r'\b\d+\.\d+\b', new_annotation.spanned_text)
                    if len(str_abi_value) > 0:
                        extracted_abi_value = str_abi_value[0]
                        new_annotation.attributes["ABI-Value"] = extracted_abi_value     
                        # convert to float, compare to a threshold
                        try:
                            float_abi_value = float(extracted_abi_value)
                             # create new attribute if +ve pad if above threshold 1 and below = 0
                            if float_abi_value < 0.90:
                                 new_annotation.attributes["PAD positive"] = 1
                            else:
                                new_annotation.attributes["PAD negative"] = 0  
                            
                            document.annotations.append(new_annotation)
                            
                        except:
                            continue
        
        return document 
    
    def getTargetRegexes(self):
        target_regexes = []
        regexes = [r'(\babi\b|ankle brachial index)( \w{0,20}){0,10} \d+\.\d+']
        for reg in regexes:
            target_regexes.append(re.compile(reg, re.IGNORECASE))
        return target_regexes

# %% [markdown]
# Once your pipeline class is defined, you can use it multiple times for different set of rules.

# %%
# configure your rules 

# ------------- SENTENCE RULES

sentence_rules='KB/rush_rules.tsv'

# ------------- TARGET RULES

target_rules_pad='KB/pad_targets.yml'
target_rules_abi='KB/abi_targets.yml'

# ------------- CONTEXT RULES 

context_rules='KB/pad_modifiers.yml'

# ------------- FEATURE INFERENCE RULES

feature_inference_rule='KB/pad_featurer_inferences.csv'

# ------------- DOCUMENT INFERENCE RULES

document_inference_rule='KB/pad_doc_inferences.csv'

# %% [markdown]
# Select documents from the MIMIC database, write a script to process all of them, and output a dictionary which uses document name as keys and document level classification as values.

# %%
#initiate an instance of MyPipe for PAD
myPipe = MyPipe(sentence_rules, target_rules_pad, context_rules, feature_inference_rule, document_inference_rule)

# %%
#initiate an instance of MyPipe for ABI
# myPipe_abi = MyPipe(sentence_rules, target_rules_abi, context_rules, feature_inference_rule, document_inference_rule)

# %%
try:
    conn.close()
except:
    print("Conn already closed!")

# %%
conn = pymysql.connect(host="mysql.chpc.utah.edu",
                       port=3306,user="mimicclass",
                       passwd=getpass.getpass("Enter MySQL passwd for user:"),db='mimic3')
 
cursor = conn.cursor()

# %%
df_docs_text = pd.read_sql('SELECT subject_id, text from NOTEEVENTS \
                        where \
                        (subject_id in (select subject_id from DIAGNOSES_ICD where ICD9_CODE in ("443.9")) AND text like "% ABI %")\
                        OR (subject_id in (select subject_id from DIAGNOSES_ICD where ICD9_CODE in ("443.9")) AND lower(text) like "% peripheral artery disease %")\
                        OR (subject_id in (select subject_id from DIAGNOSES_ICD where ICD9_CODE in ("443.9")) AND lower(text) like "% peripheral vascular disease %")\
                        OR (subject_id in (select subject_id from DIAGNOSES_ICD where ICD9_CODE in (443.9")) AND lower(text) like "% peripheral arterial occlusive disease %")\
                        OR (subject_id in (select subject_id from DIAGNOSES_ICD where ICD9_CODE in ("443.9")) AND lower(text) like "% ankle brachial index %")\
                        OR (subject_id in (select subject_id from DIAGNOSES_ICD where ICD9_CODE in ("443.9")) AND lower(text) like "% pvd %")\
                           LIMIT 75',conn)

# %%
# write to BRAT folder

unid = 'uxxxxxxx'
path = "/home/"+str(unid)+"/BRAT/"+str(unid)+"/Project_1"

for index, row in df_docs_text.iterrows():
    new_file_path_txt = path+"/"+str(row.subject_id) + "_" + str(index) + ".txt" 
    new_file_path_ann = path+"/"+str(row.subject_id) + "_" + str(index) + ".ann" 
    f=open(new_file_path_txt, "w")
    f.write(row.text)
    f.close()
    f=open(new_file_path_ann, "w")
    f.write("")
    f.close()

# %% [markdown]
# ### Error Analysis - Validation

# %%
path_1 = "/home/u0410167/BRAT/uxxxxxxx/training_data"
path_2 = "/home/u0410167/BRAT/uxxxxxxx/testing_data"

# %%
test_docs=dict()
test_doc_paths = glob.glob(str(path_1+'/*.txt')) 
for d in test_doc_paths:
    doc = Document()
    
    #print(d)
    doc.load_document_from_file(d)
    if (len(doc.text.strip()))==0:
        continue
    #print(str(d[:-3])+'ann')
    doc.load_annotations_from_brat(str(d[:-3])+'ann')
    #print(os.path.basename(d))
    test_docs[os.path.basename(d)]=doc
    myPipe.process(doc.text, doc)
    myPipe.abi_extraction(doc)


test_docs
# Out:
# ABI 1.13
# ABI 1.02
# ABI 1.13
# ABI 1.02
# ABI is 0.76
# ABI is 1.0
# ABI 1.13
# ABI 1.02
# ABI was 0.88
# ABI 0.81
# ABI 0.62
# ABI 0.47
# ABI 0.28
# ABI 1.13
# ABI 1.02
# {'10757_24.txt': <pipeUtils.Document at 0x7faf97df8fd0>,
#  '10757_25.txt': <pipeUtils.Document at 0x7faf97e50f28>,
#  '13948_3.txt': <pipeUtils.Document at 0x7faf97cf2f98>,
#  '16013_22.txt': <pipeUtils.Document at 0x7fb0418957f0>,
#  '16022_88.txt': <pipeUtils.Document at 0x7faf97de7208>,
#  '16490_67.txt': <pipeUtils.Document at 0x7faf980912b0>,
#  '18123_40.txt': <pipeUtils.Document at 0x7faf97b94c50>,
#  '19583_69.txt': <pipeUtils.Document at 0x7faf97e16358>,
#  '19583_70.txt': <pipeUtils.Document at 0x7faf97df8240>,
#  '19583_71.txt': <pipeUtils.Document at 0x7faf9805fcf8>,
#  '19583_72.txt': <pipeUtils.Document at 0x7faf97d01400>,
#  '19632_41.txt': <pipeUtils.Document at 0x7faf97cf2160>,
#  '19689_8.txt': <pipeUtils.Document at 0x7faf97deaef0>,
#  '21458_33.txt': <pipeUtils.Document at 0x7faf9805fc88>,
#  '21458_35.txt': <pipeUtils.Document at 0x7faf97ce7400>,
#  '21_92.txt': <pipeUtils.Document at 0x7faf980813c8>,
#  '21_93.txt': <pipeUtils.Document at 0x7faf97d1bfd0>,
#  '2243_59.txt': <pipeUtils.Document at 0x7faf97cdf198>,
#  '22853_80.txt': <pipeUtils.Document at 0x7faf98081d30>,
#  '23258_94.txt': <pipeUtils.Document at 0x7faf9805ff28>,
#  '24535_84.txt': <pipeUtils.Document at 0x7faf97dffa58>,
#  '24573_14.txt': <pipeUtils.Document at 0x7faf97c63d68>,
#  '24856_95.txt': <pipeUtils.Document at 0x7faf97e506d8>,
#  '25164_0.txt': <pipeUtils.Document at 0x7faf97e16588>,
#  '25188_50.txt': <pipeUtils.Document at 0x7faf97e50198>,
#  '25354_73.txt': <pipeUtils.Document at 0x7faf97b35278>,
#  '25879_36.txt': <pipeUtils.Document at 0x7faf97e50588>,
#  '25889_39.txt': <pipeUtils.Document at 0x7faf98091400>,
#  '26494_63.txt': <pipeUtils.Document at 0x7fb00f2c41d0>,
#  '2718_1.txt': <pipeUtils.Document at 0x7faf97c90400>,
#  '31118_26.txt': <pipeUtils.Document at 0x7faf97b61198>,
#  '3210_89.txt': <pipeUtils.Document at 0x7faf980b1128>,
#  '3210_90.txt': <pipeUtils.Document at 0x7faf97ce6a90>,
#  '32234_68.txt': <pipeUtils.Document at 0x7faf97e50b70>,
#  '323_61.txt': <pipeUtils.Document at 0x7faf97de7400>,
#  '57911_9.txt': <pipeUtils.Document at 0x7faf97e04400>,
#  '60436_2.txt': <pipeUtils.Document at 0x7faf97e10550>,
#  '61447_16.txt': <pipeUtils.Document at 0x7fb00f529b70>,
#  '62438_19.txt': <pipeUtils.Document at 0x7faf97d070f0>,
#  '665_4.txt': <pipeUtils.Document at 0x7faf97dea048>,
#  '75568_25.txt': <pipeUtils.Document at 0x7faf980914e0>,
#  '75568_26.txt': <pipeUtils.Document at 0x7faf97b94400>,
#  '75568_27.txt': <pipeUtils.Document at 0x7faf97df2c18>,
#  '75568_28.txt': <pipeUtils.Document at 0x7faf97e015c0>,
#  '75568_37.txt': <pipeUtils.Document at 0x7faf97cdfba8>,
#  '75568_38.txt': <pipeUtils.Document at 0x7faf98081438>,
#  '7815_46.txt': <pipeUtils.Document at 0x7faf97e16f98>,
#  '8137_7.txt': <pipeUtils.Document at 0x7faf97c7ff60>,
#  '9058_15.txt': <pipeUtils.Document at 0x7faf97cdffd0>,
#  '91529_20.txt': <pipeUtils.Document at 0x7fb041570fd0>}

# %%
[(anno.type, anno.getSpan()) for anno in test_docs['10757_24.txt'].annotations]
# Out:
# [('PAD', (567, 570)),
#  ('PAD_DOC', (0, 14)),
#  ('PAD', (9079, 9106)),
#  ('pad_nlp', (567, 570)),
#  ('historical', (506, 511)),
#  ('pad_nlp', (2638, 2641)),
#  ('pad_nlp', (6733, 6736)),
#  ('historical', (6668, 6673)),
#  ('pad_nlp', (9125, 9128)),
#  ('pad_nlp', (9079, 9106)),
#  ('historical', (8935, 8940)),
#  ('conj', (9037, 9042))]

# %%
test_docs['10757_24.txt'].annotations[7].attributes
# Out:
# {}

# %% [markdown]
# ### Validation for PAD

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span('PAD','pad_nlp', False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %% [markdown]
# #### Negation for PAD mention level

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('PAD', 'Negation', 'Negated'),('pad_nlp', 'Negation', 'Negated')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

#for a in tp_list_total:
#    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %% [markdown]
# #### Affirmation for PAD mention level -- not right since the pipeline doesn't do affirmation attribute

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('PAD', 'Negation', 'Affirmed'),('pad_nlp', 'Negation', 'Affirmed')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

#for a in tp_list_total:
#    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 0 FP = 117 FN = 87
# 265050688447726460978795573442514302308 pad_nlp 392 395
# 265248045800549493443741091422801278308 pad_nlp 11631 11634
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 266395153920638770226162721249499067748 pad_nlp 9079 9106
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392
# 268699642092087298162374983876055709028 pad_nlp 528 555
# 268704388651303527738840213094120338788 pad_nlp 762 765
# 268836957174230520541718610509020050788 pad_nlp 5710 5713
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642
# 270593649945831047708158471231361037668 pad_nlp 3231 3234
# 271689806434607401095073692943597745508 pad_nlp 3705 3732
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741
# 274893505728454324127811145730645865828 pad_nlp 255 282
# 274915180176873351422646611549139285348 pad_nlp 1378 1405
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068]
# 275610083259751337643889202118580811108 pad_nlp 891 894
# 275621134796140452376340125564213179748 pad_nlp 1446 1449
# 275671814674855951845168587822924608868 pad_nlp 3865 3868
# 275699588107225327208712004654714893668 pad_nlp 5584 5587
# 275762220346537728595509828953774011748 pad_nlp 7921 7924
# 276198060014500072715115545772648871268 pad_nlp 372 399
# 276223539791564660126085629507076928868 pad_nlp 1643 1670
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319
# 278964241587902599509577050479954015588 pad_nlp 564 567
# 278990067592037374255702418001445041508 pad_nlp 1790 1793
# 279221076314606715355397417839197730148 pad_nlp 11643 11646
# 279787451510845936254978881735206679908 pad_nlp 779 782
# 280613676065372940758426147337769629028 pad_nlp 2067 2094
# 280760710066211787944062374007121687908 pad_nlp 9726 9753
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282741032249325077629793771883681068388 pad_nlp 6525 6552
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388]
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108]
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 287835586116047682487678488976811144548 pad_nlp 11277 11280
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290
# 289447613808868538972176169993915118948 pad_nlp 2348 2351
# 289517184850653939629660436872144663908 pad_nlp 6556 6559
# 290247228792733502655199267925318219108 pad_nlp 1100 1103
# 290379458219124934406712764972110493028 pad_nlp 7876 7879
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068]
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 294434616237259655134421027109903578468 pad_nlp 3687 3714
# 294859361585625126818833519969412887908 pad_nlp 66 69
# 294887404393747050681124754850634315108 pad_nlp 1615 1618
# 294887454307489434667657438783323026788 pad_nlp 1586 1613
# 296042593786412782425980926160266376548 pad_nlp 632 635
# 296092357787569616999066807050911921508 pad_nlp 3390 3393
# 296911274336386305760014444159495877988 pad_nlp 1615 1618
# 296948537718061639705914815685657408868 pad_nlp 3384 3387
# 297008523736746064663837015616775304548 pad_nlp 6981 7008
# 298408767420631666290156770235675620708 pad_nlp 5035 5062
# 298439977770690910440664995004031481188 pad_nlp 6517 6544
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 299559562819404356934850003597822047588 pad_nlp 533 536
# 299599304458003137069230301178750088548 pad_nlp 2711 2714
# 299812396523901502431621896987573794148 pad_nlp 12342 12345
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 301021330340608785389884648835916281188 pad_nlp 13640 13667
# 301039566286774693612468554846965118308 pad_nlp 14133 14160
# 301747069816618948433962022646268081508 pad_nlp 3230 3233
# 302334295488387048279267979503686956388 pad_nlp 403 406
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 303349186858590895592470127250624525668 pad_nlp 2327 2352
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453
# T1 PAD 11631 11634 PVD [Negation:Affirmed]
# T2 PAD 392 395 PVD [Negation:Affirmed]
# T1 PAD 567 570 PVD [Negation:Affirmed]
# T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# T1 PAD 417 420 PVD [Negation:Affirmed]
# T3 PAD 1389 1392 PVD [Negation:Affirmed]
# T1 PAD 5710 5713 PVD [Negation:Affirmed]
# T2 PAD 762 765 PVD [Negation:Affirmed]
# T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 3231 3234 PVD [Negation:Affirmed]
# T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# T2 PAD 1006 1009 PVD [Negation:Affirmed]
# T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 557 560 PVD [Negation:Affirmed]
# T2 PAD 891 894 PVD [Negation:Affirmed]
# T3 PAD 1446 1449 PVD [Negation:Affirmed]
# T4 PAD 3865 3868 PVD [Negation:Affirmed]
# T5 PAD 5584 5587 PVD [Negation:Affirmed]
# T6 PAD 7921 7924 PVD [Negation:Affirmed]
# T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 1245 1248 PVD [Negation:Affirmed]
# T2 PAD 10316 10319 PVD [Negation:Affirmed]
# T1 PAD 11643 11646 PVD [Negation:Affirmed]
# T2 PAD 564 567 PVD [Negation:Affirmed]
# T3 PAD 1790 1793 PVD [Negation:Affirmed]
# T1 PAD 779 782 PVD [Negation:Affirmed]
# T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# T5 PAD 10216 10219 PVD [Negation:Affirmed]
# T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# T1 PAD 6911 6914 PVD [Negation:Affirmed]
# T2 PAD 525 528 PVD [Negation:Affirmed]
# T8 PAD 2151 2154 PVD [Negation:Affirmed]
# T9 PAD 579 582 PVD [Negation:Affirmed]
# T1 PAD 380 383 PVD [Negation:Affirmed]
# T2 PAD 11277 11280 PVD [Negation:Affirmed]
# T1 PAD 5535 5538 PVD [Negation:Affirmed]
# T1 PAD 1288 1291 PVD [Negation:Affirmed]
# T3 PAD 2348 2351 PVD [Negation:Affirmed]
# T4 PAD 6556 6559 PVD [Negation:Affirmed]
# T1 PAD 1100 1103 PVD [Negation:Affirmed]
# T2 PAD 7876 7879 PVD [Negation:Affirmed]
# T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]
# T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# T6 PAD 1615 1618 PVD [Negation:Affirmed]
# T7 PAD 66 69 PVD [Negation:Affirmed]
# T1 PAD 632 635 PVD [Negation:Affirmed]
# T3 PAD 3390 3393 PVD [Negation:Affirmed]
# T1 PAD 1615 1618 PVD [Negation:Affirmed]
# T2 PAD 3384 3387 PVD [Negation:Affirmed]
# T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# T1 PAD 533 536 PVD [Negation:Affirmed]
# T2 PAD 2711 2714 PVD [Negation:Affirmed]
# T3 PAD 12342 12345 PVD [Negation:Affirmed]
# T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# T1 PAD 3230 3233 PVD [Negation:Affirmed]
# T1 PAD 403 406 PVD [Negation:Affirmed]
# T2 PAD 4659 4662 PVD [Negation:Affirmed]
# T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 1394 1397 PVD [Negation:Affirmed]
# T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# T1 PAD 2450 2453 PVD [Negation:Affirmed]

# %% [markdown]
# ### Validation for ABI

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span('ABI_value','abi_annotation', False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 15 FP = 0 FN = 9
# Precision= 1.0
# Recall= 0.625
# NLP_75568_27.txt_0 abi_annotation 2547 2555 ABI 1.13 [ABI-Value:1.13][PAD negative:0] || T3 ABI_value 2551 2555 1.13
# NLP_75568_27.txt_1 abi_annotation 2562 2570 ABI 1.02 [ABI-Value:1.02][PAD negative:0] || T5 ABI_value 2566 2570 1.02
# NLP_75568_37.txt_0 abi_annotation 2750 2758 ABI 1.13 [ABI-Value:1.13][PAD negative:0] || T3 ABI_value 2754 2758 1.13
# NLP_75568_37.txt_1 abi_annotation 2765 2773 ABI 1.02 [ABI-Value:1.02][PAD negative:0] || T5 ABI_value 2769 2773 1.02
# NLP_13948_3.txt_0 abi_annotation 7787 7798 ABI is 0.76 [ABI-Value:0.76][PAD positive:1] || T5 ABI_value 7794 7798 0.76
# NLP_13948_3.txt_1 abi_annotation 7981 7991 ABI is 1.0 [ABI-Value:1.0][PAD negative:0] || T6 ABI_value 7988 7991 1.0
# NLP_75568_28.txt_0 abi_annotation 2750 2758 ABI 1.13 [ABI-Value:1.13][PAD negative:0] || T2 ABI_value 2754 2758 1.13
# NLP_75568_28.txt_1 abi_annotation 2765 2773 ABI 1.02 [ABI-Value:1.02][PAD negative:0] || T4 ABI_value 2769 2773 1.02
# NLP_665_4.txt_0 abi_annotation 1590 1602 ABI was 0.88 [ABI-Value:0.88][PAD positive:1] || T3 ABI_value 1598 1602 0.88
# NLP_8137_7.txt_0 abi_annotation 2274 2282 ABI 0.81 [ABI-Value:0.81][PAD positive:1] || T2 ABI_value 2278 2282 0.81
# NLP_8137_7.txt_1 abi_annotation 2303 2311 ABI 0.62 [ABI-Value:0.62][PAD positive:1] || T7 ABI_value 2307 2311 0.62
# NLP_8137_7.txt_2 abi_annotation 2350 2358 ABI 0.47 [ABI-Value:0.47][PAD positive:1] || T9 ABI_value 2354 2358 0.47
# NLP_8137_7.txt_3 abi_annotation 2370 2378 ABI 0.28 [ABI-Value:0.28][PAD positive:1] || T10 ABI_value 2374 2378 0.28
# NLP_75568_38.txt_0 abi_annotation 2506 2514 ABI 1.13 [ABI-Value:1.13][PAD negative:0] || T3 ABI_value 2510 2514 1.13
# NLP_75568_38.txt_1 abi_annotation 2521 2529 ABI 1.02 [ABI-Value:1.02][PAD negative:0] || T5 ABI_value 2525 2529 1.02
# T2 ABI_value 7381 7384 0.6
# T4 ABI_value 1635 1639 0.46
# T6 ABI_value 1757 1761 0.79
# T7 ABI_value 1781 1785 0.31
# T4 ABI_value 796 799 .99
# T6 ABI_value 2287 2291 0.92
# T8 ABI_value 2316 2320 0.74
# T2 ABI_value 1813 1815 .5
# T3 ABI_value 1825 1827 .8

# %% [markdown]
# ### ????  ABI doesn't have negations, we need to find the values associated with ABI

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('PAD', 'Negation', 'Negated'),('pad_nlp', 'DEFINITE_NEGATED_EXISTENCE'.lower(), 'Negated')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %% [markdown]
# #### We use ABI value to tell if the it is PAD positive or PAD negative

# %%
# ABI value catching PAD positive

tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('ABI', 'ABI-Value', 'Normal'),('abi_annotation', 'ABI-Value', 'Normal')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %%
# for normal ABI values

tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('ABI', 'ABI-Value', 'Normal'),('abi_annotation', 'ABI-Value', 'Normal')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %%
# for abnormal ABI values

tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('ABI', 'ABI-Value', 'Abnormal'),('abi_annotation', 'ABI-Value', 'Abnormal')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %%
# for missing ABI values

tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
attributes_to_compare=[]
# To compare attributes, create a list of tuples for each pair to compare:
# attributes_to_compare.append[(A1_type, A1_att_name, A1_att_value),(A2_type, A2_att_name, A2_att_value)]
attributes_to_compare.append([('ABI', 'ABI-Value', 'Missing'),('abi_annotation', 'ABI-Value', 'Missing')])

for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).\
    compare_types_by_span_and_attributes('PAD','pad_nlp', attributes_to_compare , False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %% [markdown]
# ### Validation Document level

# %%
tp_total = 0
fp_total = 0
fn_total = 0
tp_list_total = []
fp_list_total= []
fn_list_total = []
for doc_id in test_docs.keys():
    tp, fp, fn, tp_list, fp_list, fn_list = (test_docs.get(doc_id)).compare_types_by_span('PAD','pad_nlp', False)
    tp_total = tp_total + tp
    fp_total = fp_total + fp
    fn_total = fn_total + fn
    tp_list_total.extend(tp_list)
    fp_list_total.extend(fp_list)
    fn_list_total.extend(fn_list)

print('TP =',tp_total, 'FP =',fp_total, 'FN =',fn_total)

if tp_total > 0 :
    precision = tp_total / (tp_total + fp_total)
    print('Precision=',round(precision,3))

if tp_total > 0 :
    recall = tp_total / (tp_total + fn_total)
    print('Recall=',round(recall,3))

for a in tp_list_total:
    print(a[0].toString(),'||', a[1].toString())
for a in fp_list_total:
    print(a.toString())
for a in fn_list_total:
    print(a.toString())
# Out:
# TP = 86 FP = 31 FN = 1
# Precision= 0.735
# Recall= 0.989
# 265050688447726460978795573442514302308 pad_nlp 392 395   || T2 PAD 392 395 PVD [Negation:Affirmed]
# 265248045800549493443741091422801278308 pad_nlp 11631 11634   || T1 PAD 11631 11634 PVD [Negation:Affirmed]
# 266244882657079590199692422374336279908 pad_nlp 567 570  [historical:266245995812762915613635611666838500708] || T1 PAD 567 570 PVD [Negation:Affirmed]
# 266395153920638770226162721249499067748 pad_nlp 9079 9106   || T3 PAD 9079 9106 Peripheral Vascular Disease [Negation:Affirmed]
# 267831718963347411195408860156991419748 pad_nlp 417 420  [family:267833669560708512383400413209048692068] || T1 PAD 417 420 PVD [Negation:Affirmed]
# 267847345133840099550712434830316189028 pad_nlp 1389 1392   || T3 PAD 1389 1392 PVD [Negation:Affirmed]
# 268699642092087298162374983876055709028 pad_nlp 528 555   || T4 PAD 528 555 peripheral vascular disease [Negation:Affirmed]
# 268704388651303527738840213094120338788 pad_nlp 762 765   || T2 PAD 762 765 PVD [Negation:Affirmed]
# 268836957174230520541718610509020050788 pad_nlp 5710 5713   || T1 PAD 5710 5713 PVD [Negation:Affirmed]
# 269711693924946634241717779007813236068 pad_nlp 462 489  [historical:269712246145239358664150806009147077988] || T1 PAD 463 490 peripheral vascular disease [Negation:Affirmed]
# 269809720553580658078692143131245458788 pad_nlp 6615 6642   || T3 PAD 6615 6642 Peripheral vascular disease [Negation:Affirmed]
# 270593649945831047708158471231361037668 pad_nlp 3231 3234   || T1 PAD 3231 3234 PVD [Negation:Affirmed]
# 271689806434607401095073692943597745508 pad_nlp 3705 3732   || T1 PAD 3705 3733  Peripheral vascular disease [Negation:Affirmed]
# 272451269096813620786328619785716544868 pad_nlp 2033 2060  [historical:272451716735931826379836023309035943268] || T1 PAD 2033 2060 peripheral vascular disease [Negation:Affirmed]
# 272934678145831154356868876327812642148 pad_nlp 1006 1009   || T2 PAD 1006 1009 PVD [Negation:Affirmed]
# 274372516385111399554020143486586893668 pad_nlp 16714 16741   || T1 PAD 16714 16741 Peripheral vascular disease [Negation:Affirmed]
# 274893505728454324127811145730645865828 pad_nlp 255 282   || T1 PAD 256 283 peripheral vascular disease [Negation:Affirmed]
# 274915180176873351422646611549139285348 pad_nlp 1378 1405   || T2 PAD 1379 1406 Peripheral vascular disease [Negation:Affirmed]
# 275606347651888790080371666521322468708 pad_nlp 557 560  [probable_existence:275606764392023615110787408562501236068] || T1 PAD 557 560 PVD [Negation:Affirmed]
# 275610083259751337643889202118580811108 pad_nlp 891 894   || T2 PAD 891 894 PVD [Negation:Affirmed]
# 275621134796140452376340125564213179748 pad_nlp 1446 1449   || T3 PAD 1446 1449 PVD [Negation:Affirmed]
# 275671814674855951845168587822924608868 pad_nlp 3865 3868   || T4 PAD 3865 3868 PVD [Negation:Affirmed]
# 275699588107225327208712004654714893668 pad_nlp 5584 5587   || T5 PAD 5584 5587 PVD [Negation:Affirmed]
# 275762220346537728595509828953774011748 pad_nlp 7921 7924   || T6 PAD 7921 7924 PVD [Negation:Affirmed]
# 276198060014500072715115545772648871268 pad_nlp 372 399   || T1 PAD 373 400 peripheral vascular disease [Negation:Affirmed]
# 276223539791564660126085629507076928868 pad_nlp 1643 1670   || T2 PAD 1644 1671 Peripheral vascular disease [Negation:Affirmed]
# 277589834207812899483746550543258269028 pad_nlp 1245 1248  [historical:277590234310033596518651397940207465828] || T1 PAD 1245 1248 PVD [Negation:Affirmed]
# 277746249615375060709597228751769613668 pad_nlp 10316 10319   || T2 PAD 10316 10319 PVD [Negation:Affirmed]
# 278964241587902599509577050479954015588 pad_nlp 564 567   || T2 PAD 564 567 PVD [Negation:Affirmed]
# 278990067592037374255702418001445041508 pad_nlp 1790 1793   || T3 PAD 1790 1793 PVD [Negation:Affirmed]
# 279221076314606715355397417839197730148 pad_nlp 11643 11646   || T1 PAD 11643 11646 PVD [Negation:Affirmed]
# 279787451510845936254978881735206679908 pad_nlp 779 782   || T1 PAD 779 782 PVD [Negation:Affirmed]
# 280613676065372940758426147337769629028 pad_nlp 2067 2094   || T1 PAD 2068 2095 Peripheral vascular disease [Negation:Affirmed]
# 280760710066211787944062374007121687908 pad_nlp 9726 9753   || T2 PAD 9727 9754 peripheral vascular disease [Negation:Affirmed]
# 281658419022648912588746790574314796388 pad_nlp 636 663  [historical:281659067109018279271028305763828544868] || T1 PAD 636 663 peripheral vascular disease [Negation:Affirmed]
# 281809982497538700266563240151307564388 pad_nlp 8884 8911  [historical:281811179635074290800704278600397141348] || T2 PAD 8884 8911 peripheral vascular disease [Negation:Affirmed]
# 281816384133069852825040798502494713188 pad_nlp 9423 9450   || T3 PAD 9424 9451 peripheral vascular disease [Negation:Affirmed]
# 281833276369599519124459118008145851748 pad_nlp 10216 10219  [historical:281833513261805436774828522704557356388] || T5 PAD 10216 10219 PVD [Negation:Affirmed]
# 281833323114215402540418298199076549988 pad_nlp 10174 10201  [historical:281833513261805436774828522704557356388] || T4 PAD 10174 10201 Peripheral vascular disease [Negation:Affirmed]
# 282741032249325077629793771883681068388 pad_nlp 6525 6552   || T3 PAD 6525 6552 peripheral vascular disease [Negation:Affirmed]
# 282803029871055739759247471895697995108 pad_nlp 8889 8916  [acute:282803196250197019714356418337993700708][historical:282803246163939403700889102270682412388] || T4 PAD 8889 8916 peripheral vascular disease [Negation:Affirmed]
# 285916962864492376154848063451575924068 pad_nlp 525 528  [family:285919633645850732005668341818141750628] || T2 PAD 525 528 PVD [Negation:Affirmed]
# 286035934250168670912108656853718971748 pad_nlp 6911 6914  [family:286038974234764343234742121135093364068][probable_existence:286036435764437386205365623986924598628] || T1 PAD 6911 6914 PVD [Negation:Affirmed]
# 286651527565525003103489982122555651428 pad_nlp 579 582  [family:286654198346883358954310260489121477988] || T9 PAD 579 582 PVD [Negation:Affirmed]
# 286683881177969328088389681730114860388 pad_nlp 2151 2154   || T8 PAD 2151 2154 PVD [Negation:Affirmed]
# 287606957407480269888684799199326549348 pad_nlp 380 383  [family:287608752717642843118574668905241163108] || T1 PAD 380 383 PVD [Negation:Affirmed]
# 287835586116047682487678488976811144548 pad_nlp 11277 11280   || T2 PAD 11277 11280 PVD [Negation:Affirmed]
# 288635117910342006193147113687066391908 pad_nlp 5535 5538  [acute:288635469683383569526806029022205883748] || T1 PAD 5535 5538 PVD [Negation:Affirmed]
# 289424464924345121218018088322505946468 pad_nlp 1287 1290   || T1 PAD 1288 1291 PVD [Negation:Affirmed]
# 289447613808868538972176169993915118948 pad_nlp 2348 2351   || T3 PAD 2348 2351 PVD [Negation:Affirmed]
# 289517184850653939629660436872144663908 pad_nlp 6556 6559   || T4 PAD 6556 6559 PVD [Negation:Affirmed]
# 290247228792733502655199267925318219108 pad_nlp 1100 1103   || T1 PAD 1100 1103 PVD [Negation:Affirmed]
# 290379458219124934406712764972110493028 pad_nlp 7876 7879   || T2 PAD 7876 7879 PVD [Negation:Affirmed]
# 290961335197641696266587781677442184548 pad_nlp 896 923  [indication:290961859688077540696502650938393408868] || T11 PAD 896 923 peripheral vascular disease [Negation:Affirmed]
# 291131047467718626476216784367138420068 pad_nlp 8238 8265   || T13 PAD 8238 8265 Peripheral Vascular Disease [Negation:Affirmed]
# 292096399052465554584408440952809895268 pad_nlp 568 593  [historical:292096826092261506469188070154702206308] || T3 PAD 568 593 peripheral artery disease [Negation:Affirmed]
# 292141517906454177839381212361647240548 pad_nlp 3078 3103   || T1 PAD 3078 3103 Peripheral artery disease [Negation:Affirmed]
# 292273182436046882886167667440073618788 pad_nlp 9557 9582  [historical:292273695834539975319075273604871796068] || T2 PAD 9557 9582 peripheral artery disease [Negation:Affirmed]
# 294434616237259655134421027109903578468 pad_nlp 3687 3714   || T1 PAD 3687 3714 Peripheral vascular disease [Negation:Affirmed]
# 294859361585625126818833519969412887908 pad_nlp 66 69   || T7 PAD 66 69 PVD [Negation:Affirmed]
# 294887404393747050681124754850634315108 pad_nlp 1615 1618   || T6 PAD 1615 1618 PVD [Negation:Affirmed]
# 294887454307489434667657438783323026788 pad_nlp 1586 1613   || T5 PAD 1586 1613 Peripheral vascular disease [Negation:Affirmed]
# 296042593786412782425980926160266376548 pad_nlp 632 635   || T1 PAD 632 635 PVD [Negation:Affirmed]
# 296092357787569616999066807050911921508 pad_nlp 3390 3393   || T3 PAD 3390 3393 PVD [Negation:Affirmed]
# 296911274336386305760014444159495877988 pad_nlp 1615 1618   || T1 PAD 1615 1618 PVD [Negation:Affirmed]
# 296948537718061639705914815685657408868 pad_nlp 3384 3387   || T2 PAD 3384 3387 PVD [Negation:Affirmed]
# 297008523736746064663837015616775304548 pad_nlp 6981 7008   || T4 PAD 6981 7008 Peripheral vascular disease [Negation:Affirmed]
# 298408767420631666290156770235675620708 pad_nlp 5035 5062   || T1 PAD 5035 5062 Peripheral vascular disease [Negation:Affirmed]
# 298439977770690910440664995004031481188 pad_nlp 6517 6544   || T2 PAD 6517 6544 peripheral vascular disease [Negation:Affirmed]
# 299559562819404356934850003597822047588 pad_nlp 533 536   || T1 PAD 533 536 PVD [Negation:Affirmed]
# 299599304458003137069230301178750088548 pad_nlp 2711 2714   || T2 PAD 2711 2714 PVD [Negation:Affirmed]
# 299812396523901502431621896987573794148 pad_nlp 12342 12345   || T3 PAD 12342 12345 PVD [Negation:Affirmed]
# 300793877377973084473660847250654672228 pad_nlp 2772 2799  [historical:300796918947132007081581063402908071268] || T1 PAD 2772 2799 Peripheral vascular disease [Negation:Affirmed]
# 300938083725691797565088360336419239268 pad_nlp 9541 9568   || T2 PAD 9541 9568 Peripheral vascular disease [Negation:Affirmed]
# 301021330340608785389884648835916281188 pad_nlp 13640 13667   || T3 PAD 13640 13667 Peripheral Vascular Disease [Negation:Affirmed]
# 301039566286774693612468554846965118308 pad_nlp 14133 14160   || T4 PAD 14133 14160 peripheral vascular disease [Negation:Affirmed]
# 301747069816618948433962022646268081508 pad_nlp 3230 3233   || T1 PAD 3230 3233 PVD [Negation:Affirmed]
# 302334295488387048279267979503686956388 pad_nlp 403 406   || T1 PAD 403 406 PVD [Negation:Affirmed]
# 302418362907067683882601737118509479268 pad_nlp 4659 4662   || T2 PAD 4659 4662 PVD [Negation:Affirmed]
# 303349186858590895592470127250624525668 pad_nlp 2327 2352   || T1 PAD 2328 2353 peripheral artery disease [Negation:Affirmed]
# 304193515048252409497057517645839250788 pad_nlp 415 442  [historical:304194168680593152177842664383429522788] || T1 PAD 417 444 peripheral vascular disease [Negation:Affirmed]
# 304224543965819495982232653198548841828 pad_nlp 2440 2467   || T2 PAD 2441 2468 Peripheral vascular disease [Negation:Affirmed]
# 304946947936187808497697338808591496548 pad_nlp 1394 1397   || T1 PAD 1394 1397 PVD [Negation:Affirmed]
# 305675801871266407272885514831631005028 pad_nlp 748 775  [historical:305676214649993106590084377195612255588] || T1 PAD 749 776 peripheral vascular disease [Negation:Affirmed]
# 305812068764819565935042778878132401508 pad_nlp 7464 7491   || T2 PAD 7465 7492 Peripheral vascular disease [Negation:Affirmed]
# 306670430638907231481748113713270142308 pad_nlp 2450 2453   || T1 PAD 2450 2453 PVD [Negation:Affirmed]
# 266283858159346857397928190385264571748 pad_nlp 2638 2641
# 266364422108681112232253561486603236708 pad_nlp 6733 6736  [historical:266365905259883379260653312629353526628]
# 266395113514275887951350548542084396388 pad_nlp 9125 9128
# 274038896892424959282777617072435541348 pad_nlp 432 435  [acute:274039319970812785454340366597130335588]
# 274064153246071256468315687012923651428 pad_nlp 1877 1880
# 274178351134956066799236269392058955108 pad_nlp 7569 7572  [historical:274179400115827755659066007913961403748]
# 281833261316248641414234975234795287908 pad_nlp 10203 10206  [historical:281833513261805436774828522704557356388]
# 281853570663427547934533704291024418148 pad_nlp 11082 11085
# 281909538229709249405253159672981271908 pad_nlp 13223 13248
# 282721172918109252130932574157089846628 pad_nlp 5490 5493
# 282763199496914943648809069545545577828 pad_nlp 7585 7588
# 284740517348105692430858920235508217188 pad_nlp 14631 14655  [historical:284740899227849011184966121117348836708][probable_existence:284741155134813932258776548264308421988]
# 285957511045785551500185063309918385508 pad_nlp 2771 2798
# 287632868978030560040294767748283938148 pad_nlp 1593 1596
# 293036827834130370559923296418024174948 pad_nlp 1050 1053
# 293182687673600756348076386766032254308 pad_nlp 9278 9281
# 298520367418067633893447660308679406948 pad_nlp 11466 11493
# 300754559610043755653486675129860928868 pad_nlp 490 493  [historical:300755115791744605789136581808392287588]
# 300906214197320434735291357282396583268 pad_nlp 7974 7977
# 300908420701646456997093337481413440868 pad_nlp 8128 8131
# 300933937715947426112302090181498156388 pad_nlp 9338 9341  [historical:300934363171180127711794967512511460708]
# 300939308593084268091747556525891433828 pad_nlp 9619 9622
# 302363617039051952367967974184266806628 pad_nlp 1821 1848
# 302400499333265592702404520764027221348 pad_nlp 3548 3575  [probable_existence:302400989755591555998654224801079801188]
# 303305534517890411370386212340307899748 pad_nlp 399 402
# 304926728909114168238743466392465749348 pad_nlp 386 389  [historical:304927191601583251542475012689135711588]
# 305007485382883332735409189805603730788 pad_nlp 3840 3843
# 305028720115000405863171011455172785508 pad_nlp 4921 4924  [historical:305029293726897009136975188713373218148][probable_existence:305030276948393811157404724593796887908]
# 305049527015039901963509827967410025828 pad_nlp 5950 5953
# 305108453753191511207238402215911929188 pad_nlp 8006 8033
# 306632533431931783421146993835505923428 pad_nlp 539 566  [historical:306632844006328839337350360527791240548]
# T12 PAD 1456 1483 Peripheral Vascular Disease [Negation:Affirmed]

# %% [markdown]
# ### System Deployment

# %%
try:
    conn.close()
except:
    print("Conn already closed!")
# Out:
# Conn already closed!

# %%
conn = pymysql.connect(host="mysql.chpc.utah.edu",
                       port=3306,user="mimicclass",
                       passwd=getpass.getpass("Enter MySQL passwd for user:"),db='mimic3')
 
cursor = conn.cursor()
# Out:
# Enter MySQL passwd for user:········

# %%
pad_data = pd.read_sql("""SELECT subject_id, text FROM NOTEEVENTS limit 500 """,conn)

# %%
pad_data.count()
# Out:
# subject_id    500
# text          500
# dtype: int64

# %%
pad_data.head()
# Out:
#    subject_id                                               text
# 0       23224  Admission Date:  [**2823-9-29**]              ...
# 1       23224  Admission Date:  [**2830-3-12**]              ...
# 2       19051  Admission Date:  [**2714-3-12**]              ...
# 3       14605  Admission Date:  [**2678-10-4**]              ...
# 4        9446  Admission Date:  [**2936-5-6**]     Discharge ...

# %%
final_nlp_system = MyPipe(sentence_rules, target_rules_pad, context_rules, feature_inference_rule, document_inference_rule)

# %%
output = []
counter = 0
for index , row in pad_data.sample(500).iterrows():    
    doc = Document(document_id=str(row.subject_id) + '_' + str(index), text=row.text)
    
    final_nlp_system.process(doc.text, doc)
    
    # print(doc.document_id)
    
    if(len(doc.annotations) > 0):
        i = 1
        for a in doc.annotations:
            if( a.type == 'pad_nlp'):
                neg_flag = 0
                # Switch the flag to 1 when the mention is negated
                if('definite_negated_existence' in a.attributes):
                    neg_flag=1
                ### Each row in the dictionary
                record_id  = str(row.subject_id) + '_' + str(index)+'_'+str(i)
                subject_id =  row.subject_id
                note_id = str(row.subject_id) + '_' + str(index)
                annotation_type = a.type
                snippet = doc.text[int(a.start_index): int(a.end_index)]
                out_list = [record_id, subject_id, note_id, annotation_type, \
                            a.start_index, a.end_index, \
                            snippet, neg_flag]
                output.append(out_list)
                i=i+1
                counter=counter+1
                # Print . after 10 identified records
                if counter%10 == 0:
                    print('.', end='')
        else:
            continue
        break
# Out:
# .........

# %%
output_abi = []
counter = 0
for index , row in pad_data.sample(500).iterrows():    
    doc = Document(document_id=str(row.subject_id) + '_' + str(index), text=row.text)
    final_nlp_system.abi_extraction(doc)
    if(len(doc.annotations) > 0):
        i = 1
        for a in doc.annotations:
            if( a.type == 'abi_annotation'):
                neg_flag = 0
                abi_output_value = 0.0
                # Switch the flag to 1 when the mention is negated
                if('ABI-Value' in a.attributes):
                    abi_output_value = a.attributes.get("ABI-Value")
                if('PAD positive' in a.attributes):
                    pad_positive = a.attributes.get("PAD positive")
                ### Each row in the dictionary
                record_id  = str(row.subject_id) + '_' + str(index)+'_'+str(i)
                subject_id =  row.subject_id
                note_id = str(row.subject_id) + '_' + str(index)
                annotation_type = a.type
                snippet = doc.text[int(a.start_index): int(a.end_index)]
                out_list = [record_id, subject_id, note_id, annotation_type, \
                            a.start_index, a.end_index, \
                            snippet, abi_output_value, pad_positive]
                
                output_abi.append(out_list)
                i=i+1
                counter=counter+1
                # Print . after 10 identified records
                if counter%10 == 0:
                    print('.', end='')
        else:
            continue
        break

# %%
output_doc_class = []
counter = 0
for index, row in pad_data.sample(500).iterrows():    
    doc = Document(document_id=str(row.subject_id) + '_' + str(index), text=row.text) 
    doc_class, b, c, d = final_nlp_system.process(doc.text, doc)
         
    if(len(doc.annotations) > 0):
        i = 1
        for a in doc.annotations:
            if( a.type == 'pad_doc'):
                neg_flag = 0
            else:
                neg_flag = 1
                ### Each row in the dictionary
                record_id  = str(row.subject_id) + '_' + str(index)+'_'+str(i)
                subject_id =  row.subject_id
                note_id = str(row.subject_id) + '_' + str(index)
                annotation_type = a.type
                snippet = doc.text[int(a.start_index): int(a.end_index)]
                out_list = [record_id, subject_id, note_id, annotation_type, \
                            a.start_index, a.end_index, \
                            snippet, neg_flag]
                output_doc_class.append(out_list)
                i=i+1
                counter=counter+1
                # Print . after 10 identified records
                if counter%10 == 0:
                    print('.', end='')
        else:
            continue
        break
# Out:
# ............

# %% [markdown]
# ### Output to CSV file

# %%
columns=['record_id','subject_id', 'note_id', 'annotation_type', 'span_start', 'span_end', 'PAD_snippet', 'neg_flag']
result_data_frame_pad = (pd.DataFrame(output, columns=columns))

result_data_frame_pad.describe()
# Out:
#          subject_id    span_start      span_end   neg_flag
# count     99.000000     99.000000     99.000000  99.000000
# mean   24219.656566   3445.828283   3459.979798   0.020202
# std    23312.340745   3455.295209   3454.574211   0.141407
# min     1136.000000    199.000000    226.000000   0.000000
# 25%     7666.000000    950.000000    975.500000   0.000000
# 50%    18764.000000   2012.000000   2039.000000   0.000000
# 75%    27869.000000   5314.500000   5317.500000   0.000000
# max    92724.000000  13025.000000  13028.000000   1.000000

# %%
columns=['record_id','subject_id', 'note_id', 'annotation_type', 'span_start', 'span_end', 'ABI_snippet', 'abi_output_value', 'pad_positive']
result_data_frame_abi = (pd.DataFrame(output_abi, columns=columns))

result_data_frame_abi.describe()
# Out:
#         record_id  subject_id  note_id  annotation_type  span_start  span_end  \
# count           0           0        0                0           0         0
# unique          0           0        0                0           0         0
#
#         ABI_snippet  abi_output_value  pad_positive
# count             0                 0             0
# unique            0                 0             0

# %%
columns=['record_id','subject_id', 'note_id', 'annotation_type', 'span_start', 'span_end', 'PAD_snippet', 'neg_flag']
result_data_frame_doc = (pd.DataFrame(output_doc_class, columns=columns))

result_data_frame_doc.describe()
# Out:
#          subject_id    span_start      span_end  neg_flag
# count    129.000000    129.000000    129.000000     129.0
# mean   24485.434109   3418.682171   3430.922481       1.0
# std    22739.559235   3418.519647   3418.006559       0.0
# min     1136.000000    199.000000    226.000000       1.0
# 25%    10634.000000    982.000000    988.000000       1.0
# 50%    21449.000000   2031.000000   2039.000000       1.0
# 75%    27869.000000   5045.000000   5048.000000       1.0
# max    92724.000000  13025.000000  13028.000000       1.0

# %%
result_data_frame_pad.to_csv('out_table_pad.csv', index=False)
print('Done')
# Out:
# Done

# %%
result_data_frame_abi.to_csv('out_table_abi.csv', index=False)
print('Done')
# Out:
# Done

# %%
result_data_frame_doc.to_csv('out_table_doc.csv', index=False)
print('Done')
# Out:
# Done
